# %% [markdown]
# # ch8: Plotting and visualization

# %% [markdown]
# ### setup

# %%
# inport the numpy library
import numpy as np
import pandas as pd
from numpy import random
import matplotlib.pyplot as plt

# deaults
np.set_printoptions(precision=4)
plt.rc('figure', figsize=(10, 8))

# %% [markdown]
# ## A brief matplotlib API primer

# %%
plot(np.arange(10))

# %% [markdown]
# ### Figures and subplot

# %%
fig = plt.figure()

# %%
f = plt.gcf()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot()
# Out:
# []

# %%
# should have reproduced figure 8-3 (page 222)
np.random.seed(1)
plt.plot(np.random.rand(50).cumsum(), 'k--')

# %%
np.random.seed(1)
ax3.plot(np.random.rand(50).cumsum(), 'k--')
plt.show()

# %%
# figure 8-3
np.random.seed(1)
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax1.hist(randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
ax3.plot(np.random.rand(50).cumsum(), 'k--')
plt.plot()
# Out:
# []

# %%
fig, axes = plt.subplots(2, 3)
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B2C6FD0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BD1C5F8>]], dtype=object)

# %%
np.random.seed(1)
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(10,8))
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Color, Markers, and Line Styles

# %%
np.random.seed(1)
plt.plot(randn(30).cumsum(), 'ko--')

# %%
np.random.seed(1)
plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
np.random.seed(1)
data = randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %% [markdown]
# ### Ticks, Labels, and Legends

# %%
plt.xlim()
f = plt.gcf()

# %%
np.random.seed(1)
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum())
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_ylim([-20, 50])
ax.set_title('my first matplotlib plot')
ax.set_xlabel('Stages')

# %%
np.random.seed(1)
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k'  , label='one'  )
ax.plot(randn(1000).cumsum(), 'r--', label='two'  )
ax.plot(randn(1000).cumsum(), 'b.' , label='three')
ax.legend(loc='best')

# %% [markdown]
# ### Annotations and Drawing on a Subplot

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.text(0.5, 0.5, 'Hello world!', family='monospace', fontsize=15)

# %%
import os
from datetime import datetime

# load data
df = pd.read_csv('data/ch08/spx.csv', index_col=0, parse_dates=True)
spx = df['SPX']
spx.head()

# create figure
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
spx.plot(ax=ax, style='k-')
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in 2008-2009 financial crisis')

# annotate
crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008,  3, 12), 'Bear Stearns Fails'),
    (datetime(2008,  9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
                xytext=(date, spx.asof(date) + 200),
                arrowprops=dict(facecolor='black'),
                horizontalalignment='left', verticalalignment='top')

# done
plt.show()

# %%
fig  = plt.figure()
ax   = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
plt.savefig('fig8p12.png', dpi=400, bbox_inches='tight')
plt.savefig('fig8p12.pdf', dpi=400, bbox_inches='tight')
plt.show()

# %%
plt.rc('figure', figsize=(10, 8))
plt.subplot(1,1,1)

# %% [markdown]
# ## Plotting Functions in pandas

# %% [markdown]
# ### line plots

# %%
np.random.seed(1)
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
np.random.seed(1)
df = pd.DataFrame(np.random.randn(10,4).cumsum(0), columns=['a','b','c','d'], index=np.arange(0,100,10))
df.head()
# Out:
#            a         b         c         d
# 0   1.624345 -0.611756 -0.528172 -1.072969
# 10  2.489753 -2.913295  1.216640 -1.834176
# 20  2.808792 -3.162665  2.678748 -3.894316
# 30  2.486375 -3.546720  3.812517 -4.994207
# 40  2.313947 -4.424578  3.854731 -4.411392

# %%
df.plot()

# %% [markdown]
# ### Bar plots

# %%
np.random.seed(1)
f, a = plt.subplots(2,1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar' , ax=a[0], color='k', alpha=0.7)
data.plot(kind='barh', ax=a[1], color='k', alpha=0.7)
plt.show()

# %%
np.random.seed(1)
df = pd.DataFrame(np.random.rand(6, 4), 
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='genus'))
df
# Out:
# genus         A         B         C         D
# one    0.417022  0.720324  0.000114  0.302333
# two    0.146756  0.092339  0.186260  0.345561
# three  0.396767  0.538817  0.419195  0.685220
# four   0.204452  0.878117  0.027388  0.670468
# five   0.417305  0.558690  0.140387  0.198101
# six    0.800745  0.968262  0.313424  0.692323

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh', stacked=True, alpha=0.5)

# %%
df_tips = pd.read_csv('data/ch08/tips.csv')
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
party_counts = pd.crosstab(df_tips.day, df_tips.size)
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
# drop size 1 and 6
party_counts = party_counts.ix[:, 2:5]
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_counts.sum(axis=1).astype(float)
# Out:
# day
# Fri     18
# Sat     85
# Sun     75
# Thur    58
# dtype: float64

# %%
# normalize so each row sums to one to get proportion/day
party_pcts = party_counts.div(party_counts.sum(axis=1).astype(float), axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot(kind='bar', stacked=True)

# %% [markdown]
# ### Histograms and Density Plots
