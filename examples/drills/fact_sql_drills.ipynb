# %%
import itertools as it
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# plotting options
# %matplotlib inline
np.set_printoptions(linewidth=250)
plt.rc('font'  , size=18)
plt.rc('figure', figsize=(10, 8))
plt.rc('axes'  , labelsize=22)
plt.rc('legend', fontsize=16)

np.set_printoptions(precision=3)
plt.rc('figure', figsize=(10, 8))

# %%
os.chdir('%s/examples/drills' % os.getenv('DST'))
pwd = os.getcwd()
print(pwd)
# Out:
# /home/cloudera/Development/dst/examples/drills

# %%
import os
spark_home = os.environ.get('SPARK_HOME', None)
spark_home
# Out:
# '/usr/lib/spark'

# %%
from pyspark import SparkContext, SparkConf, SQLContext

from pyspark import SparkContext, SparkConf, SQLContext, HiveContext

myConf = SparkConf().setAppName('TestApp')\
                    .set('spark.executor.memory', '2G')\
                    .set('spark.hadoop.validateOutputSpecs', 'false')

sc      = SparkContext(conf=myConf)
sql_ctx = HiveContext(sc)

# %% [markdown]
# ## Load Tables

# %%
def run_sql(sql):
    return sql_ctx.sql(sql).toPandas()

# %%
users_df = sql_ctx.load(
    source      = 'com.databricks.spark.csv',
    header      = 'true',
    inferSchema = 'true',
    path        = 'file:%s/users.txt'%pwd
)
users_df.registerTempTable('users')
run_sql('select * from users')
# Out:
#    user_id user_name  age
# 0        0      Ryan   38
# 1        1     Randy   38
# 2        2       Jen   32
# 3        3  Scarlett    1
# 4        4      Mike   35
# 5        5      Reid   40
# 6        6     Clark   65
# 7        7    Dianne   65

# %%
programs_df = sql_ctx.load(
    source      = 'com.databricks.spark.csv',
    header      = 'true',
    inferSchema = 'true',
    path        = 'file:%s/programs.txt'%pwd,
)
programs_df.registerTempTable('programs')
run_sql('select * from programs')
# Out:
#    program_id       program_name program_start_time program_end_time  \
# 0           0   Sesame Street E1               8:00             8:30
# 1           1   Sesame Street E2               8:00             8:30
# 2           2    Hartof Dixie E1              20:00            21:00
# 3           3    Hartof Dixie E2              20:00            21:00
# 4           4  Premier League G1               4:00             6:00
# 5           5  Premier League G2               6:00             8:00
#
#    duration is_rerun  series_id   genre
# 0        30     True          0    kids
# 1        30     True          0    kids
# 2        60    False          1   drama
# 3        60    False          1   drama
# 4        60    False          2  sports
# 5        60    False          2  sports

# %%
programs_df = sql_ctx.r

# %%
programs_df = sql_ctx.load(
    source      = 'com.databricks.spark.csv',
    header      = 'true',
    inferSchema = 'true',
    path        = 'file:%s/views.txt'%pwd
)
programs_df.registerTempTable('views')
run_sql('select * from views')
# Out:
#    user_id  program_id  seconds_viewed viewing_start_time viewing_end_time
# 0        0           5            4500               4:05             5:20
# 1        0           6            4560               6:05             8:21
# 2        0           3            3600              20:00            21:00
# 3        1           5            4500               4:05             5:20
# 4        3           0            1800               8:00             8:30
# 5        3           1             600               8:00             8:10
# 6        3           1             600               8:20             8:30
# 7        2           2            3600              20:00            21:00
# 8        2           3            3000              20:00            20:50
# 9        2           3             300              20:55            21:00

# %%
commercials_df = sql_ctx.load(
    source      = 'com.databricks.spark.csv',
    header      = 'true',
    inferSchema = 'true',
    path        = 'file:%s/commercials.txt'%pwd
)
commercials_df.registerTempTable('commercials')
run_sql('select * from commercials')
# Out:
#    commercial_id commercial_name  cost
# 0              0            toys   200
# 1              1         diapers   300
# 2              2           legos   250
# 3              3           shoes   350
# 4              4        best buy   150

# %%
spots_df = sql_ctx.load(
    source      = 'com.databricks.spark.csv',
    header      = 'true',
    inferSchema = 'true',
    path        = 'file:%s/spots.txt'%pwd
)
spots_df.registerTempTable('spots')
run_sql('select * from spots')
# Out:
#     spot_id  commercial_id  program_id spot_start_time spot_end_time  \
# 0         0              0           0         8:08:00       8:08:20
# 1         1              1           0         8:08:20       8:08:40
# 2         2              2           0         8:08:40       8:09:00
# 3         3              0           0         8:18:00       8:18:20
# 4         4              1           0         8:18:20       8:18:40
# 5         5              2           0         8:18:40       8:19:00
# 6         6              0           1         8:08:00       8:08:20
# 7         7              1           1         8:08:20       8:08:40
# 8         8              2           1         8:08:40       8:09:00
# 9         9              0           1         8:18:00       8:18:20
# 10       10              1           1         8:18:20       8:18:40
# 11       11              2           1         8:18:40       8:19:00
# 12       12              3           4         4:08:00       4:08:20
# 13       13              4           4         4:08:20       4:08:40
# 14       14              3           4         4:08:40       4:09:00
# 15       15              3           4         4:18:00       4:18:20
# 16       16              4           4         4:18:20       4:18:40
# 17       17              3           4         4:18:40       4:19:00
# 18       18              3           5         6:08:00       6:08:20
# 19       19              4           5         6:08:20       6:08:40
# 20       20              3           5         6:08:40       6:09:00
# 21       21              3           5         6:18:00       6:18:20
# 22       22              4           5         6:18:20       6:18:40
# 23       23              3           5         6:18:40       6:19:00
#
#     spot_duration
# 0              20
# 1              20
# 2              20
# 3              20
# 4              20
# 5              20
# 6              20
# 7              20
# 8              20
# 9              20
# 10             20
# 11             20
# 12             20
# 13             20
# 14             20
# 15             20
# 16             20
# 17             20
# 18             20
# 19             20
# 20             20
# 21             20
# 22             20
# 23             20

# %% [markdown]
# ## Fact table questions
#
# A the fact table is something simple like: views
#
# * user_id, program_id, seconds_viewed, viewing_start_time, viewing_end_time

# %% [markdown]
# #### How many programs did each user watch?

# %%
sql = """\
select
    v.user_id as uid
  , count(distinct v.program_id) as n_watched
from views v
group by user_id
"""
run_sql(sql)
# Out:
#    uid  n_watched
# 0    0          3
# 1    1          1
# 2    2          2
# 3    3          2

# %% [markdown]
# get user info

# %%
sql = """\
select 
    u.user_name
  , u.age
  , c.n_watched
from users u
    inner join (    
        select
            v.user_id as uid
          , count(distinct v.program_id) as n_watched
        from views v
        group by user_id
    ) c on c.uid=u.user_id
"""
run_sql(sql)
# Out:
#   user_name  age  n_watched
# 0      Ryan   38          3
# 1     Randy   38          1
# 2       Jen   32          2
# 3  Scarlett    1          2

# %%
sql = """\
select 
    u.user_name
  , u.age
  , c.n_watched as n_watched_raw
  , nvl(c.n_watched, 0) as n_watched
from users u
    left join (    
        select
            v.user_id as uid
          , count(distinct v.program_id) as n_watched
        from views v
        group by user_id
    ) c on c.uid=u.user_id
"""
run_sql(sql)
# Out:
#   user_name  age  n_watched_raw  n_watched
# 0      Ryan   38              3          3
# 1     Randy   38              1          1
# 2       Jen   32              2          2
# 3  Scarlett    1              2          2
# 4      Mike   35            NaN          0
# 5      Reid   40            NaN          0
# 6     Clark   65            NaN          0
# 7    Dianne   65            NaN          0

# %% [markdown]
# #### How many users for each program?

# %%
sql = """\
select
    v.program_id as pid
  , count(distinct v.user_id) as n_users
from views v
group by program_id
"""
run_sql(sql)
# Out:
#    pid  n_users
# 0    0        1
# 1    1        1
# 2    2        1
# 3    3        2
# 4    5        2
# 5    6        1

# %%
sql = """\
select 
    p.program_name
  , nvl(c.n_users, 0) as n_users
from programs p
    left join (
        select
            v.program_id as pid
          , count(distinct v.user_id) as n_users
        from views v
        group by program_id
    ) c on c.pid=p.program_id
"""
run_sql(sql)
# Out:
#         program_name  n_users
# 0   Sesame Street E1        1
# 1   Sesame Street E2        1
# 2    Hartof Dixie E1        1
# 3    Hartof Dixie E2        2
# 4  Premier League G1        0
# 5  Premier League G2        2

# %% [markdown]
# #### how many users watched 1+ (one or more) programs?  2+, 3+?

# %%
sql = """\
select
    sum(case when c.n_programs >=1 then 1 else 0 end) as n_1plus
  , sum(case when c.n_programs >=2 then 1 else 0 end) as n_2plus
  , sum(case when c.n_programs >=3 then 1 else 0 end) as n_3plus
from (
    select
        v.user_id as uid
      , count(distinct v.program_id) as n_programs
    from views v
    group by user_id
) c
"""
run_sql(sql)
# Out:
#    n_1plus  n_2plus  n_3plus
# 0        4        3        1

# %% [markdown]
# ## Randy's version

# %% [markdown]
# #### commute the number of spots seen by person.

# %%
sql = """\
select 
"""
run_sql(sql)
