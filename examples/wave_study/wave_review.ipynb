# %% [markdown]
# # Wave Review
#
# Review of basic wave and their spectral composition.

# %% [markdown]
# ## Notebook Setup

# %%
# setup notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from IPython.display import display, Math, Latex
import os
os.chdir('%s/examples/wave_study' % os.getenv('DST'))
print(os.getcwd())
np.set_printoptions(precision=4)
plt.rc('figure', figsize=(10, 8))

# use floating point division for integers
from __future__ import division
# Out:
# C:\Users\J28976\Documents\Development\dst\examples\wave_study

# %% [markdown]
# ## 1-D Wave Equation and Basic Properties
#
# Deriving the wave equation is beyond the scope of this exercise.  It can be shown using classical mechanics that the general 1-D wave equation is
#
# \begin{align}
# \frac{d^2\Psi}{dx^2} - \frac{1}{c^2}\frac{d^2\Psi}{dt^2} = 0
# \end{align}
#
# Solutions of the wave equation are given by a linear combination of sinusoids (or complex exponentials):
#
# \begin{align}
# \Psi(x, t) &\sim \sum_{r} a_r \Psi_r(x, t) \\
#            &\sim \sum_{r} a_r\ {\rm exp}\left\{ \pm i \frac{\omega_r}{v}(x \pm vt) \right\}
# \end{align}
#
# We need only consider one $\Psi_r(x, t)$ since the $a_r$ can absorb the $\pm$ in the form of a complex phase shift.  So without loss of generality, we drop the subscript $r$ for now and only consider solutions of the form:
#
# \begin{align}
# \Psi(x, t) \sim {\rm exp}\left\{ - i \frac{\omega}{v}(x - vt) \right\}
# \end{align}
#
# It is customary to define the *progagation constant* or *wave number* $k$ (dimensions $[L^{-1}]$) by:
#
# $$k^2 = \frac{\omega^2}{v^2}$$
#
# Also, the wavelength $\lambda$ is the distance required to complete one vibration or cycle:
#
# $$\lambda = \frac{v}{f} = \frac{2 \pi v}{\omega}$$
#
# and can be related to $k$ by
#
# $$k = \frac{2 \pi}{\lambda} = \frac{\omega}{v}$$
#
# So, we can recast the expression for $\Psi(x,t)$ as
#
# \begin{align}
# \Psi(x, t) &\sim e^{ -i k(x - vt)} \\
#            &= e^{i(\omega t - k x)}
# \end{align}

# %% [markdown]
# ### plot of a single sinusoid:
#
# Variables in code:
# * x = spatial coord [m]
# * t = time coord [s]
# * f = freq of wave [hz]
# * w = $\omega$ or angular freq of wave [rad/s]
# * k = $k$ or wave number of wave [m$^{-1}$]
# * A = amplitude of wave [m]

# %% [markdown]
# #### fixed position x

# %%
A   = 1   # amplitude
f   = 2   # freq
x   = 0   # x position
v   = 1   # m/s
fs  = 200 # sampling frequency
t0  = 0   # intial time
tf  = 2   # final time
phi = np.pi*0.25

dt   = np.abs(t0-tf)/fs
w    = 2*np.pi*f
k    = w/v
t    = np.arange(t0, tf+dt, dt)
psi1 = A*np.cos(w*t - k*x)

#change x to 7
x = 7.7
psi2 = A*np.cos(w*t - k*x)
# Out:
# 0.01

# %% [markdown]
# plot for fixed x

# %%
plt.plot(t, psi1, linewidth=2, color='red')
plt.plot(t, psi2, linewidth=2, color='blue')
plt.xlabel('time (s)')
plt.ylabel('$\Psi(x=fixed, t)$')
plt.axis([t0, tf,-1.5,1.5])
plt.tight_layout()
plt.legend(['x = 0', 'x = 7.7'])
plt.show()

# %% [markdown]
# #### fixed t

# %%
A   = 1   # amplitude
f   = 2   # freq
t   = 0   # time
v   = 1   # m/s
fs  = 100 # sampling frequency
x0  = 0   # initial position
xf  = 2   # final final

dx   = np.abs(x0-xf)/fs
w    = 2*np.pi*f
k    = w/v
x    = np.arange(x0, xf+dx, dx)

# try 3 times
times = np.arange(0, 0.3, 0.1)
psi   = np.array([A*np.cos(w*t - k*x) for t in times])

# %%
plt.plot(x, psi[0], linewidth=2, color='red')
plt.plot(x, psi[1], linewidth=2, color='blue')
plt.plot(x, psi[2], linewidth=2, color='green')
plt.xlabel('x (m)')
plt.ylabel('$\Psi(x, t=fixed)$')
plt.axis([t0, tf,-1.5,1.5])
plt.tight_layout()
plt.legend([('t = %0.1f'%t) for t in times])
plt.show()

# %% [markdown]
# #### visualize both x and t

# %%
A    = 1   # amplitude
f    = 2   # freq
t    = 0   # time
v    = 1   # m/s
w    = 2*np.pi*f
k    = w/v

x_fs = 100 # spatial sampling frequency
x0   = 0   # initial position
xf   = 2   # final final
dx   = np.abs(xf-x0)/x_fs
x    = np.arange(x0, xf, dx)

t_fs = 100 # time sampling freq
t0   = 0   # initial time
tf   = 10  # final time
dt   = np.abs(tf-t0)/t_fs
t    = np.arange(t0, tf, dt)

# construct array of values
psi  = np.array([A*np.cos(w*t_fixed - k*x) for t_fixed in t])

# %%
psi.shape
# Out:
# (100L, 100L)

# %%
psi[0,:]
# Out:
# array([ 1.    ,  0.9686,  0.8763,  0.729 ,  0.5358,  0.309 ,  0.0628,
#        -0.1874, -0.4258, -0.6374, -0.809 , -0.9298, -0.9921, -0.9921,
#        -0.9298, -0.809 , -0.6374, -0.4258, -0.1874,  0.0628,  0.309 ,
#         0.5358,  0.729 ,  0.8763,  0.9686,  1.    ,  0.9686,  0.8763,
#         0.729 ,  0.5358,  0.309 ,  0.0628, -0.1874, -0.4258, -0.6374,
#        -0.809 , -0.9298, -0.9921, -0.9921, -0.9298, -0.809 , -0.6374,
#        -0.4258, -0.1874,  0.0628,  0.309 ,  0.5358,  0.729 ,  0.8763,
#         0.9686,  1.    ,  0.9686,  0.8763,  0.729 ,  0.5358,  0.309 ,
#         0.0628, -0.1874, -0.4258, -0.6374, -0.809 , -0.9298, -0.9921,
#        -0.9921, -0.9298, -0.809 , -0.6374, -0.4258, -0.1874,  0.0628,
#         0.309 ,  0.5358,  0.729 ,  0.8763,  0.9686,  1.    ,  0.9686,
#         0.8763,  0.729 ,  0.5358,  0.309 ,  0.0628, -0.1874, -0.4258,
#        -0.6374, -0.809 , -0.9298, -0.9921, -0.9921, -0.9298, -0.809 ,
#        -0.6374, -0.4258, -0.1874,  0.0628,  0.309 ,  0.5358,  0.729 ,
#         0.8763,  0.9686])

# %%
psi[1,:]
# Out:
# array([ 0.309 ,  0.5358,  0.729 ,  0.8763,  0.9686,  1.    ,  0.9686,
#         0.8763,  0.729 ,  0.5358,  0.309 ,  0.0628, -0.1874, -0.4258,
#        -0.6374, -0.809 , -0.9298, -0.9921, -0.9921, -0.9298, -0.809 ,
#        -0.6374, -0.4258, -0.1874,  0.0628,  0.309 ,  0.5358,  0.729 ,
#         0.8763,  0.9686,  1.    ,  0.9686,  0.8763,  0.729 ,  0.5358,
#         0.309 ,  0.0628, -0.1874, -0.4258, -0.6374, -0.809 , -0.9298,
#        -0.9921, -0.9921, -0.9298, -0.809 , -0.6374, -0.4258, -0.1874,
#         0.0628,  0.309 ,  0.5358,  0.729 ,  0.8763,  0.9686,  1.    ,
#         0.9686,  0.8763,  0.729 ,  0.5358,  0.309 ,  0.0628, -0.1874,
#        -0.4258, -0.6374, -0.809 , -0.9298, -0.9921, -0.9921, -0.9298,
#        -0.809 , -0.6374, -0.4258, -0.1874,  0.0628,  0.309 ,  0.5358,
#         0.729 ,  0.8763,  0.9686,  1.    ,  0.9686,  0.8763,  0.729 ,
#         0.5358,  0.309 ,  0.0628, -0.1874, -0.4258, -0.6374, -0.809 ,
#        -0.9298, -0.9921, -0.9921, -0.9298, -0.809 , -0.6374, -0.4258,
#        -0.1874,  0.0628])
